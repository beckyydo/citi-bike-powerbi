# %%
# Import Dependencies
import pandas as pd

# %%
# Import monthly datasets
citi_01 = pd.read_csv("asset/data/201911-citibike-tripdata.csv")
citi_02 = pd.read_csv("asset/data/201912-citibike-tripdata.csv")
citi_03 = pd.read_csv("asset/data/202001-citibike-tripdata.csv")
citi_04 = pd.read_csv("asset/data/202002-citibike-tripdata.csv")

# %%
# Concat the multiple datasets into one dataset
citi_df = pd.concat([citi_01, citi_02, citi_03, citi_04], ignore_index = True)

# %%
# Display preview of dataframe
citi_df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           273  2019-11-01 00:00:00.2930  2019-11-01 00:04:34.1880
# 1           159  2019-11-01 00:00:03.5840  2019-11-01 00:02:43.4780
# 2           967  2019-11-01 00:00:06.2670  2019-11-01 00:16:14.0990
# 3           604  2019-11-01 00:00:21.7610  2019-11-01 00:10:25.8910
# 4           153  2019-11-01 00:00:25.2060  2019-11-01 00:02:59.0180
#
#    start station id     start station name  start station latitude  \
# 0               237        E 11 St & 2 Ave               40.730473
# 1              3572         34 Ave & 38 St               40.756913
# 2               334        W 20 St & 7 Ave               40.742388
# 3               280        E 10 St & 5 Ave               40.733320
# 4              3761  Cedar St & Myrtle Ave               40.697842
#
#    start station longitude  end station id          end station name  \
# 0               -73.986724             335  Washington Pl & Broadway
# ...

# %%
# Export final dataset for dashboard
citi_df.to_csv("asset/data/citi_df.csv")
